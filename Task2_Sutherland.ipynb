# %%
import requests
import pandas as pd

url = "https://maps.six.nsw.gov.au/arcgis/rest/services/public/NSW_POI/MapServer/0/query"

params = {
    "where": "1=1",
    "geometry": "150.93,-34.20,151.25,-33.93",
    "geometryType": "esriGeometryEnvelope",
    "spatialRel": "esriSpatialRelIntersects",
    "outFields": "*",
    "returnGeometry": "true",
    "f": "json"
}

all_features = []

offset = 0

batch_size = 1000

while True:

    params = {
        "where": "1=1",
        "geometry": "150.93,-34.20,151.25,-33.93",
        "geometryType": "esriGeometryEnvelope",
        "spatialRel": "esriSpatialRelIntersects",
        "outFields": "*",
        "returnGeometry": "true",
        "f": "json",
        "resultOffset": offset,
        "resultRecordCount": batch_size
    }

    response = requests.get(url, params=params)

    data = response.json()

    features = data.get("features", [])

    all_features.extend(features)

    print("offset:", offset, "records:", len(features))

    if len(features) < batch_size:
        break

    offset += batch_size




print(len(features))
print(features[0])

rows = []

for place in all_features:

    name = place['attributes']['poiname']

    x = place['geometry']['x']

    y = place['geometry']['y']

    rows.append(["Sutherland", name, x, y])

df = pd.DataFrame(rows, columns=['sa4_name', 'name', 'x', 'y'])

print(df)

df.to_csv('sutherland_poi.csv', index=False)

print("CSV saved")


poi_count = len(df)

summary = pd.DataFrame({
    "sa4_name": ["Sutherland"],
    "poi_count": [poi_count]
})

print(summary)

summary.to_csv("sutherland_poi_summary.csv", index=False)

print("Summary CSV saved")
# Out:
# offset: 0 records: 1000
# offset: 1000 records: 1000
# offset: 2000 records: 1000
# offset: 3000 records: 1000
# offset: 4000 records: 239
# 239
# {'attributes': {'objectid': 156404, 'topoid': 518444902, 'poigroup': 4, 'poitype': 'Roadside Emergency Telephone', 'poiname': 'FEP3432E', 'poilabel': 'FEP3432E', 'poilabeltype': 'NAMED', 'poialtlabel': None, 'poisourcefeatureoid': 135, 'accesscontrol': 1, 'startdate': 1717765223000, 'enddate': 32503680000000, 'lastupdate': 1717765289000, 'msoid': 242618, 'centroidid': None, 'shapeuuid': '29fdee65-66d8-3a39-aac8-a4fd8f951b9d', 'changetype': 'I', 'processstate': None, 'urbanity': 'U'}, 'geometry': {'x': 151.13468499728884, 'y': -33.937824142715144}}
#         sa4_name                             name           x          y
# 0     Sutherland              KOOLANGARRA RESERVE  151.056165 -34.009790
# 1     Sutherland             BILL WAKEHAM RESERVE  151.057551 -33.999863
# 2     Sutherland                  SCYLLA BAY OVAL  151.068453 -33.999300
# 3     Sutherland           CARINA BAY HORSE ARENA  151.070889 -34.004640
# 4     Sutherland            COMO COMMUNITY CHURCH  151.060867 -34.008402
# ...          ...                              ...         ...        ...
# 4234  Sutherland      MATRAVILLE JEHOVAHS WITNESS  151.232039 -33.964624
# 4235  Sutherland         OUR LADY OF GOOD COUNSEL  151.234721 -33.979827
# 4236  Sutherland       ST ANDREWS CATHOLIC CHURCH  151.247189 -33.963889
# 4237  Sutherland              BAYSIDE HIGH SCHOOL  151.137580 -33.967228
# 4238  Sutherland  PEAKHURST PARK COMMUNITY CENTRE  151.058114 -33.957058
#
# [4239 rows x 4 columns]
# CSV saved
#      sa4_name  poi_count
# 0  Sutherland       4239
# Summary CSV saved
