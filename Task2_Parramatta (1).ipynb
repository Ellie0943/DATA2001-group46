# %%
import requests
import pandas as pd

url = "https://maps.six.nsw.gov.au/arcgis/rest/services/public/NSW_POI/MapServer/0/query"


params = {
    "where": "1=1",
    "geometry": "150.90,-33.90,151.10,-33.73",
    "geometryType": "esriGeometryEnvelope",
    "spatialRel": "esriSpatialRelIntersects",
    "outFields": "*",
    "returnGeometry": "true",
    "f": "json"
}

response = requests.get(url, params=params)

print(response)

data = response.json()

print(data.keys())
features = data['features']

print(len(features))
print(features[0])

rows = []

for place in features:

    name = place['attributes']['poiname']

    x = place['geometry']['x']

    y = place['geometry']['y']

    rows.append(["Parramatta", name, x, y])

df = pd.DataFrame(rows, columns=['sa4_name', 'name', 'x', 'y'])

print(df)

df.to_csv('Parramatta_poi.csv', index=False)

print("CSV saved")


poi_count = len(df)

summary = pd.DataFrame({
    "sa4_name": ["Parramatta"],
    "poi_count": [poi_count]
})

print(summary)

summary.to_csv("Parramatta_poi_summary.csv", index=False)

print("Summary CSV saved")
# Out:
# <Response [200]>
# dict_keys(['displayFieldName', 'fieldAliases', 'geometryType', 'spatialReference', 'fields', 'features', 'exceededTransferLimit'])
# 1000
# {'attributes': {'objectid': 746, 'topoid': 500168018, 'poigroup': 1, 'poitype': 'Shopping Centre', 'poiname': 'CARLINGFORD COURT', 'poilabel': 'CARLINGFORD COURT', 'poilabeltype': 'NAMED', 'poialtlabel': None, 'poisourcefeatureoid': 25, 'accesscontrol': 1, 'startdate': 1285588392000, 'enddate': 32503680000000, 'lastupdate': 1285588392535, 'msoid': 68148, 'centroidid': None, 'shapeuuid': '3a4d6e04-672b-3da0-ad27-b99dd1f55da7', 'changetype': 'I', 'processstate': None, 'urbanity': 'U'}, 'geometry': {'x': 151.05229048007863, 'y': -33.77624547568138}}
#        sa4_name                 name           x          y
# 0    Parramatta    CARLINGFORD COURT  151.052290 -33.776245
# 1    Parramatta          ECCLES PARK  151.053743 -33.810534
# 2    Parramatta  MARRI BADOO RESERVE  151.044031 -33.801801
# 3    Parramatta          ACACIA PARK  151.049230 -33.793923
# 4    Parramatta    HOMELANDS RESERVE  151.042955 -33.788741
# ..          ...                  ...         ...        ...
# 995  Parramatta                 None  150.977972 -33.831983
# 996  Parramatta                 None  150.979823 -33.830315
# 997  Parramatta                 None  150.979090 -33.833682
# 998  Parramatta                 None  150.978014 -33.833387
# 999  Parramatta                 None  150.979282 -33.832344
#
# [1000 rows x 4 columns]
# CSV saved
#      sa4_name  poi_count
# 0  Parramatta       1000
# Summary CSV saved
