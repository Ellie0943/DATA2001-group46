# %%
import requests
import pandas as pd

url = "https://maps.six.nsw.gov.au/arcgis/rest/services/public/NSW_POI/MapServer/0/query"

params = {
    "where": "1=1",
    "geometry": "150.90,-33.90,151.10,-33.73",
    "geometryType": "esriGeometryEnvelope",
    "spatialRel": "esriSpatialRelIntersects",
    "outFields": "*",
    "returnGeometry": "true",
    "f": "json"
}

all_features = []

offset = 0

batch_size = 1000

while True:

    params = {
        "where": "1=1",
        "geometry": "150.90,-33.90,151.10,-33.73",
        "geometryType": "esriGeometryEnvelope",
        "spatialRel": "esriSpatialRelIntersects",
        "outFields": "*",
        "returnGeometry": "true",
        "f": "json",
        "resultOffset": offset,
        "resultRecordCount": batch_size
    }

    response = requests.get(url, params=params)

    data = response.json()

    features = data.get("features", [])

    all_features.extend(features)

    print("offset:", offset, "records:", len(features))

    if len(features) < batch_size:
        break

    offset += batch_size




print(len(features))
print(features[0])

rows = []

for place in all_features:

    name = place['attributes']['poiname']

    x = place['geometry']['x']

    y = place['geometry']['y']

    rows.append(["Parramatta", name, x, y])

df = pd.DataFrame(rows, columns=['sa4_name', 'name', 'x', 'y'])

print(df)

df.to_csv('parramatta_poi.csv', index=False)

print("CSV saved")


poi_count = len(df)

summary = pd.DataFrame({
    "sa4_name": ["Parramatta"],
    "poi_count": [poi_count]
})

print(summary)

summary.to_csv("parramatta_poi_summary.csv", index=False)

print("Summary CSV saved")
# Out:
# offset: 0 records: 1000
# offset: 1000 records: 1000
# offset: 2000 records: 1000
# offset: 3000 records: 1000
# offset: 4000 records: 285
# 285
# {'attributes': {'objectid': 150121, 'topoid': 517015448, 'poigroup': 2, 'poitype': 'Primary School', 'poiname': 'SACRED HEART CATHOLIC PRIMARY SCHOOL CABRAMATTA', 'poilabel': 'SACRED HEART CATHOLIC PRIMARY SCHOOL CABRAMATTA', 'poilabeltype': 'NAMED', 'poialtlabel': None, 'poisourcefeatureoid': 36, 'accesscontrol': 1, 'startdate': 1688396355000, 'enddate': 32503680000000, 'lastupdate': 1688396387087, 'msoid': 240653, 'centroidid': None, 'shapeuuid': '35e4ba89-fcf2-3529-ae9d-e1e2ed012d32', 'changetype': 'M', 'processstate': None, 'urbanity': 'U'}, 'geometry': {'x': 150.9367941810175, 'y': -33.890461575533394}}
#         sa4_name                                        name           x  \
# 0     Parramatta                           CARLINGFORD COURT  151.052290
# 1     Parramatta                                 ECCLES PARK  151.053743
# 2     Parramatta                         MARRI BADOO RESERVE  151.044031
# 3     Parramatta                                 ACACIA PARK  151.049230
# 4     Parramatta                           HOMELANDS RESERVE  151.042955
# ...          ...                                         ...         ...
# 4280  Parramatta               ERIC MOBBS RESERVE SCOUT HALL  151.006790
# 4281  Parramatta         ARDEN ANGLICAN SCHOOL JUNIOR CAMPUS  151.065328
# 4282  Parramatta                       ARDEN ANGLICAN SCHOOL  151.083674
# 4283  Parramatta         THE FEDERATION COLLEGE OF EDUCATION  150.999758
# 4284  Parramatta  OUR LADY HELP OF CHRISTIANS PRIMARY SCHOOL  151.082715
#
#               y
# 0    -33.776245
# 1    -33.810534
# 2    -33.801801
# 3    -33.793923
# 4    -33.788741
# ...         ...
# 4280 -33.750642
# 4281 -33.746552
# 4282 -33.770409
# 4283 -33.816405
# 4284 -33.770883
#
# [4285 rows x 4 columns]
# CSV saved
#      sa4_name  poi_count
# 0  Parramatta       4285
# Summary CSV saved
